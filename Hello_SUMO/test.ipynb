# %%
import time
import traci


# =========================
# 1. SUMO 設定檔位置
# =========================
CONFIG_PATH = (
    r"C:\Traffic_project\SUMO_RL"
    r"\sumo-rl\sumo_rl\nets"
    r"\2way-single-intersection"
    r"\single-intersection.sumocfg"
)


# =========================
# 2. 啟動 SUMO
# =========================
def start_sumo(use_gui=True):

    if use_gui:
        sumo_binary = "sumo-gui"
    else:
        sumo_binary = "sumo"

    sumo_cmd = [
        sumo_binary,
        "-c",
        CONFIG_PATH,
        "--start",
    ]

    traci.start(sumo_cmd)

    print("TraCI 連線成功")


# =========================
# 3. 讀取目前 state
# =========================
def get_state():

    # 每個方向的 incoming lanes
    incoming_lanes = {
        "north": ["n_t_0", "n_t_1"],
        "south": ["s_t_0", "s_t_1"],
        "east": ["e_t_0", "e_t_1"],
        "west": ["w_t_0", "w_t_1"],
    }

    state = {}

    # 計算每個方向的 queue
    for direction, lanes in incoming_lanes.items():

        total_halting = 0

        for lane_id in lanes:

            halting_num = (
                traci.lane.getLastStepHaltingNumber(lane_id)
            )

            total_halting += halting_num

        state[direction] = total_halting

    # 取得 traffic light phase
    tls_id = traci.trafficlight.getIDList()[0]

    phase = traci.trafficlight.getPhase(tls_id)

    state["phase"] = phase

    return state


# =========================
# 4. 印出 state
# =========================
def print_state(step, state):

    sim_time = traci.simulation.getTime()

    total_vehicles = len(
        traci.vehicle.getIDList()
    )

    print(
        f"\nstep={step}, "
        f"time={sim_time}, "
        f"vehicles={total_vehicles}"
    )

    print(
        f"north queue = {state['north']}"
    )

    print(
        f"south queue = {state['south']}"
    )

    print(
        f"east queue = {state['east']}"
    )

    print(
        f"west queue = {state['west']}"
    )

    print(
        f"traffic light phase = {state['phase']}"
    )


# =========================
# 5. 主程式
# =========================
def main():

    start_sumo(use_gui=True)

    try:

        for step in range(1000):

            # SUMO 往前走一步
            traci.simulationStep()

            # 取得 state
            state = get_state()

            # 印出 state
            print_state(step, state)

            # 只是方便觀察 GUI
            time.sleep(0.05)

    finally:

        traci.close()

        print("\nSUMO / TraCI 已關閉")


# =========================
# 6. 執行
# =========================
if __name__ == "__main__":
    main()
# Out:
# TraCI 連線成功
#
# step=0, time=1.0, vehicles=8
# north queue = 0
# south queue = 0
# east queue = 0
# west queue = 0
# traffic light phase = 0
#
# step=1, time=2.0, vehicles=12
# north queue = 0
# south queue = 0
# east queue = 0
# west queue = 0
# traffic light phase = 0
#
# step=2, time=3.0, vehicles=12
# north queue = 0
# south queue = 0
# east queue = 0
# west queue = 0
# traffic light phase = 0
#
# step=3, time=4.0, vehicles=12
# north queue = 0
# south queue = 0
# east queue = 0
# west queue = 0
# traffic light phase = 0
#
# step=4, time=5.0, vehicles=12
# north queue = 0
# south queue = 0
# east queue = 0
# west queue = 0
# traffic light phase = 0
#
# step=5, time=6.0, vehicles=12
# north queue = 0
# south queue = 0
# east queue = 0
# west queue = 0
# traffic light phase = 0
#
# step=6, time=7.0, vehicles=12
# north queue = 0
# south queue = 0
# east queue = 0
# west queue = 0
# traffic light phase = 0
#
# step=7, time=8.0, vehicles=12
# north queue = 0
# south queue = 0
# ...

# %%
incoming_lanes = {
        "north": ["n_t_0", "n_t_1"],
        "south": ["s_t_0", "s_t_1"],
        "east": ["e_t_0", "e_t_1"],
        "west": ["w_t_0", "w_t_1"],
    }

for direction, lanes in incoming_lanes.items():
    print(direction, lanes)
# Out:
# north ['n_t_0', 'n_t_1']
# south ['s_t_0', 's_t_1']
# east ['e_t_0', 'e_t_1']
# west ['w_t_0', 'w_t_1']

# %%
tls_id = traci.trafficlight.getIDList()[0]

programs = traci.trafficlight.getAllProgramLogics(tls_id)

for program in programs:
    print("Program ID:", program.programID)

    for i, phase in enumerate(program.phases):
        print(
            "phase =", i,
            "duration =", phase.duration,
            "state =", phase.state
        )
# Out:
# ---------------------------------------------------------------------------
# FatalTraCIError                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 tls_id = traci.trafficlight.getIDList()[0]
#       2
#       3 programs = traci.trafficlight.getAllProgramLogics(tls_id)
#       4
#
# File C:\Program Files (x86)\Eclipse\Sumo\tools\traci\domain.py:176, in Domain.getIDList(self)
#     171 def getIDList(self):
#     172     """getIDList() -> tuple(string)
#     173
#     174     Returns a tuple of all objects in the network.
#     175     """
# --> 176     return self._getUniversal(tc.TRACI_ID_LIST)
#
# File C:\Program Files (x86)\Eclipse\Sumo\tools\traci\domain.py:152, in Domain._getUniversal(self, varID, objectID, format, *values)
#     150 if self._deprecatedFor:
#     151     warnings.warn("The domain %s is deprecated, use %s instead." % (self._name, self._deprecatedFor))
# ...
